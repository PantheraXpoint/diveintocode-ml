# %%
import matplotlib.pyplot as plt
list_n_grains = []  
list_total_grains = []
grain_d = 1
list_n_grains.append(grain_d)
list_total_grains.append(grain_d)
for i in range(1,100):
    grain_d *= 2
    list_n_grains.append(grain_d)
    list_total_grains.append(list_total_grains[i - 1] + (list_n_grains[i]))
plt.plot(list_n_grains, label = "change in the number of rice grains day after day\n")
plt.plot(list_total_grains, label = "total number of rice grains on x day")
plt.legend(loc = 'best')
plt.title("the change in the number of rice grains on x day\n")
plt.xlabel("number of days")
plt.ylabel("number of rice")
plt.show()

# %%
import matplotlib.pyplot as plt
def compute_sorori_shinzaemon(day=100):
    """
    A function that verifies the anecdote of rice by Sorori Shinzaemon. Calculate the number of rice grains per day.
    Parameteres
    --------------
    day: int
        Number of days to get rice (default : 100)
    Returns
    --------------
    list_n_grains : list
        List of the number of rice you get one day (the length of the list is equal to day)
    list_total_grains : list
        List of the total number of rice you will receive by a certain day (the length of the list will be equal to day)
    """
    # Write the code here. pass is an instruction that means do nothing.
    list_n_grains = []
    list_total_grains = []
    grain_d = 1
    list_n_grains.append(grain_d)
    list_total_grains.append(grain_d)
    for i in range(1,day):
        grain_d *= 2
        list_n_grains.append(grain_d)
        list_total_grains.append(list_total_grains[i - 1] + (list_n_grains[i]))
    return list_n_grains, list_total_grains  


day = int(input("Enter the day for calculation: "))
list_n_grains, list_total_grains = compute_sorori_shinzaemon(day = 10)
plt.plot(list_n_grains, label = "change in the number of rice grains day after day")
plt.plot(list_total_grains, label = "total number of rice grains on x day")
plt.legend(loc = 'best')
plt.title("the change in the number of rice grains on x day")
plt.xlabel("number of days")
plt.ylabel("number of rice")
plt.show()
# Out:
# Enter the day for calculation: 13

# %%
import matplotlib.pyplot as plt
kg_usage = 0.2577    ## average rice comsumption for a person daily
grain_usage = 2.20462262 * kg_usage * 7000  #7000 grains of rice in 1 pound. I transfer from pound to kg and grains
def survive(num_grain,num_people):
    return int(num_grain) / int(num_people) / int(grain_usage)
num_grain = input("Enter the total number of grains: ")
num_people = input("Enter the total number of people: ")
print("The survival days are: ")
print(survive(num_grain,num_people))
# Out:
# Enter the total number of grains: 1000000000
# Enter the total number of people: 12
# The survival days are:
# 20959.08786049631
